# %% [markdown]
# <a href="https://colab.research.google.com/github/Mario-RJunior/br-python-challenges/blob/master/Desafio_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Desafio 12
#
# Escreva uma função em Python para verificar a validade de uma senha.
#
# Validação:
#
# * Pelo menos 1 letra entre [a-z] e 1 letra entre [A-Z].
# * Pelo menos 1 número entre [0-9].
# * Pelo menos 1 caractere de [$ # @].
# * Comprimento mínimo de 6 caracteres.
# * Comprimento máximo de 16 caracteres.
#
# Entradas: "12345678", "J3sus0", "#Te5t300", "J*90j12374", "Michheeul", "Monk3y6"
#
# A saída deve ser a senha e um texto indicando se a senha é válida ou inválida:
#
# ```
# "1234" - Senha inválida
# "Qw#1234" - Senha válida
# ```

# %%
lista_senhas = ['12345678',
          'J3sus0',
          '#Te5t300',
          'J*90j12374',
          'Michheeul',
          'Monk3y6',
          '1234',
          'Qw#1234']

# %%
import re
def valida_senhas(password):
    regex = re.compile(r'^(?=.*[a-z])(?=.*[A-Z])(?=.*[0-9])(?=.*[$#@]).{6,16}$',
                       flags=re.M)
    resultado = re.findall(regex, password)
    if resultado:
        print(f'"{password}" - Senha válida')
    else:
        print(f'"{password}" - Senha inválida')


for senha in lista_senhas:
    valida_senhas(senha)
# Out:
# "12345678" - Senha inválida
# "J3sus0" - Senha inválida
# "#Te5t300" - Senha válida
# "J*90j12374" - Senha inválida
# "Michheeul" - Senha inválida
# "Monk3y6" - Senha inválida
# "1234" - Senha inválida
# "Qw#1234" - Senha válida
